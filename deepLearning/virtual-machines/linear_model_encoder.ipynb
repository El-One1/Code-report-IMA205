# %%
import numpy as np
from matplotlib import pyplot as plt
import pandas as pd

import torchio as tio
import torch
from torch.utils.data import DataLoader
from torch.utils.data import Dataset
from torchvision.transforms import ToTensor
import torch.nn.functional as F
import torch.nn as nn
import torch.optim as optim


from sklearn.preprocessing import StandardScaler
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split


from functions import *

# %%
metaData = pd.read_csv('../metaDataTrain.csv')
metaDataClean = metaData.iloc
subject_list = load_training_dataset(metaDataClean)

# %% [markdown]
# ## Let us construct the features vectors

# %%
features = np.zeros((100, 14))  ## there are 5 features and 20 subjects per training class

features_metadata = select_row_x_and_y_from_table(metaDataClean, 2, 3)

## adding into features vectors
features[:,:2] = features_metadata

# %% [markdown]
# Let us add volume information to feature vectors

# %%
volumes_0_ed = []
volumes_1_ed = []
volumes_2_ed = []
volumes_3_ed = []

volumes_0_es = []
volumes_1_es = []
volumes_2_es = []
volumes_3_es = []
   
for i in range(0, 100):
    subject = subject_list[i]
    
    ed_view = subject.ed_seg
    volumes_0_ed.append(get_volume(ed_view, 0))
    volumes_1_ed.append(get_volume(ed_view, 1))
    volumes_2_ed.append(get_volume(ed_view, 2))
    volumes_3_ed.append(get_volume(ed_view, 3))

    es_view = subject.es_seg
    volumes_0_es.append(get_volume(es_view, 0))
    volumes_1_es.append(get_volume(es_view, 1))
    volumes_2_es.append(get_volume(es_view, 2))
    volumes_3_es.append(get_volume(es_view, 3))

volumes_0_ed = np.array([volumes_0_ed]).flatten()
volumes_1_ed = np.array([volumes_1_ed]).flatten() 
volumes_2_ed = np.array([volumes_2_ed]).flatten() 
volumes_3_ed = np.array([volumes_3_ed]).flatten() 

volumes_0_es = np.array([volumes_0_es]).flatten()
volumes_1_es = np.array([volumes_1_es]).flatten() 
volumes_2_es = np.array([volumes_2_es]).flatten() 
volumes_3_es = np.array([volumes_3_es]).flatten() 

######### new features
ejection_fraction_right = (volumes_1_ed - volumes_1_es) / volumes_1_ed
ejection_fraction_left = (volumes_3_ed - volumes_3_es) / volumes_3_ed

volumes_0_ed = np.array([volumes_0_ed]).flatten()
volumes_1_ed = np.array([volumes_1_ed]).flatten() / volumes_0_ed
volumes_2_ed = np.array([volumes_2_ed]).flatten() / volumes_0_ed
volumes_3_ed = np.array([volumes_3_ed]).flatten() / volumes_0_ed

volumes_0_es = np.array([volumes_0_es]).flatten()
volumes_1_es = np.array([volumes_1_es]).flatten() / volumes_0_es
volumes_2_es = np.array([volumes_2_es]).flatten() / volumes_0_es
volumes_3_es = np.array([volumes_3_es]).flatten() / volumes_0_es

ratioRL_ed = volumes_3_ed / volumes_1_ed
ratioRL_es = volumes_3_es / volumes_1_es

ratioML_ed = volumes_2_ed / volumes_1_ed
ratioML_es = volumes_2_es / volumes_1_es


"""for i, new_col in enumerate([ejection_fraction_right[:], volumes_1_ed[:], volumes_2_ed[:], volumes_3_ed[:], ejection_fraction_left[:], volumes_1_es[:], volumes_2_es[:], volumes_3_es[:]]):
    features[:,i+2] = new_col"""

for i, new_col in enumerate([ratioRL_ed[:], ratioRL_es[:], ratioML_ed[:], ratioML_es[:], ejection_fraction_right[:], volumes_1_ed[:], volumes_2_ed[:], volumes_3_ed[:], ejection_fraction_left[:], volumes_1_es[:], volumes_2_es[:], volumes_3_es[:]]):
    features[:,i+2] = new_col
# Out:
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/001/001_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/001/001_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/001/001_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/001/001_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/002/002_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/002/002_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/002/002_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/002/002_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/003/003_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/003/003_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/003/003_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/003/003_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/004/004_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/004/004_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/004/004_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/004/004_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/005/005_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/005/005_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/005/005_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/005/005_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/006/006_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/006/006_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/006/006_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/006/006_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/007/007_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/007/007_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/007/007_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/007/007_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/008/008_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/008/008_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/008/008_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/008/008_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/009/009_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/009/009_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/009/009_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/009/009_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/010/010_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/010/010_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/010/010_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/010/010_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/011/011_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/011/011_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/011/011_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/011/011_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/012/012_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/012/012_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/012/012_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/012/012_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/013/013_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/013/013_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/013/013_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/013/013_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/014/014_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/014/014_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/014/014_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/014/014_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/015/015_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/015/015_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/015/015_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/015/015_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/016/016_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/016/016_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/016/016_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/016/016_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/017/017_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/017/017_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/017/017_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/017/017_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/018/018_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/018/018_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/018/018_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/018/018_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/019/019_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/019/019_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/019/019_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/019/019_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/020/020_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/020/020_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/020/020_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/020/020_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/021/021_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/021/021_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/021/021_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/021/021_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/022/022_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/022/022_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/022/022_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/022/022_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/023/023_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/023/023_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/023/023_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/023/023_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/024/024_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/024/024_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/024/024_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/024/024_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/025/025_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/025/025_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/025/025_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/025/025_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/026/026_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/026/026_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/026/026_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/026/026_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/027/027_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/027/027_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/027/027_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/027/027_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/028/028_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/028/028_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/028/028_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/028/028_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/029/029_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/029/029_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/029/029_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/029/029_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/030/030_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/030/030_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/030/030_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/030/030_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/031/031_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/031/031_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/031/031_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/031/031_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/032/032_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/032/032_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/032/032_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/032/032_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/033/033_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/033/033_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/033/033_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/033/033_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/034/034_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/034/034_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/034/034_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/034/034_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/035/035_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/035/035_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/035/035_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/035/035_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/036/036_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/036/036_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/036/036_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/036/036_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/037/037_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/037/037_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/037/037_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/037/037_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/038/038_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/038/038_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/038/038_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/038/038_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/039/039_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/039/039_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/039/039_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/039/039_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/040/040_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/040/040_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/040/040_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/040/040_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/041/041_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/041/041_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/041/041_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/041/041_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/042/042_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/042/042_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/042/042_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/042/042_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/043/043_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/043/043_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/043/043_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/043/043_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/044/044_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/044/044_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/044/044_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/044/044_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/045/045_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/045/045_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/045/045_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/045/045_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/046/046_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/046/046_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/046/046_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/046/046_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/047/047_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/047/047_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/047/047_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/047/047_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/048/048_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/048/048_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/048/048_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/048/048_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/049/049_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/049/049_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/049/049_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/049/049_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/050/050_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/050/050_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/050/050_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/050/050_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/051/051_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/051/051_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/051/051_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/051/051_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/052/052_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/052/052_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/052/052_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/052/052_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/053/053_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/053/053_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/053/053_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/053/053_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/054/054_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/054/054_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/054/054_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/054/054_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/055/055_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/055/055_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/055/055_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/055/055_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/056/056_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/056/056_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/056/056_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/056/056_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/057/057_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/057/057_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/057/057_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/057/057_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/058/058_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/058/058_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/058/058_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/058/058_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/059/059_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/059/059_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/059/059_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/059/059_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/060/060_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/060/060_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/060/060_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/060/060_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/061/061_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/061/061_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/061/061_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/061/061_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/062/062_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/062/062_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/062/062_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/062/062_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/063/063_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/063/063_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/063/063_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/063/063_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/064/064_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/064/064_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/064/064_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/064/064_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/065/065_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/065/065_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/065/065_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/065/065_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/066/066_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/066/066_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/066/066_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/066/066_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/067/067_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/067/067_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# ...
# NiftiImageIO (0x564a5f149970): ../Train/078/078_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/079/079_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/079/079_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/079/079_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/079/079_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/080/080_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/080/080_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/080/080_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/080/080_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/081/081_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/081/081_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/081/081_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/081/081_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/082/082_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/082/082_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/082/082_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/082/082_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/083/083_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/083/083_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/083/083_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/083/083_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/084/084_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/084/084_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/084/084_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/084/084_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/085/085_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/085/085_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/085/085_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/085/085_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/086/086_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/086/086_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/086/086_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/086/086_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/087/087_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/087/087_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/087/087_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/087/087_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/088/088_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/088/088_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/088/088_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/088/088_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/089/089_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/089/089_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/089/089_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/089/089_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/090/090_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/090/090_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/090/090_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/090/090_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/091/091_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/091/091_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/091/091_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/091/091_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/092/092_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/092/092_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/092/092_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/092/092_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/093/093_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/093/093_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/093/093_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/093/093_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/094/094_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/094/094_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/094/094_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/094/094_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/095/095_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/095/095_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/095/095_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/095/095_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/096/096_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/096/096_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/096/096_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/096/096_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/097/097_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/097/097_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/097/097_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/097/097_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/098/098_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/098/098_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/098/098_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/098/098_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/099/099_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/099/099_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/099/099_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/099/099_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/100/100_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/100/100_ED_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/100/100_ES_seg.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/100/100_ES_seg.nii has unexpected scales in sform

# %% [markdown]
# Let us just give our explicit class vector

# %%
classes = np.zeros((100))
classes[:20] = 2
classes[20:40] = 3
classes[40:60] = 1
classes[60:80] = 0
classes[80:100] = 4
classes = np.array(classes.astype('int'))

# %%
shapes = np.array([subject.ed.shape for subject in subject_list])
max1, max2, max3 = shapes[:,1].max(), shapes[:,2].max(), shapes[:,3].max()
shaper = tio.CropOrPad((max1, max2, max3))

X_train_ed = np.array([shaper(subject.ed_seg) for subject in subject_list])
# Out:
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/001/001_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/002/002_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/003/003_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/004/004_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/005/005_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/006/006_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/007/007_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/008/008_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/009/009_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/010/010_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/011/011_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/012/012_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/013/013_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/014/014_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/015/015_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/016/016_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/017/017_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/018/018_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/019/019_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/020/020_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/021/021_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/022/022_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/023/023_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/024/024_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/025/025_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/026/026_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/027/027_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/028/028_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/029/029_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/030/030_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/031/031_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/032/032_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/033/033_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/034/034_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/035/035_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/036/036_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/037/037_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/038/038_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/039/039_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/040/040_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/041/041_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/042/042_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/043/043_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/044/044_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/045/045_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/046/046_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/047/047_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/048/048_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/049/049_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/050/050_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/051/051_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/052/052_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/053/053_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/054/054_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/055/055_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/056/056_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/057/057_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/058/058_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/059/059_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/060/060_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/061/061_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/062/062_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/063/063_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/064/064_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/065/065_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/066/066_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/067/067_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/068/068_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/069/069_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/070/070_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/071/071_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/072/072_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/073/073_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/074/074_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/075/075_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/076/076_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/077/077_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/078/078_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/079/079_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/080/080_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/081/081_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/082/082_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/083/083_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/084/084_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/085/085_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/086/086_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/087/087_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/088/088_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/089/089_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/090/090_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/091/091_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/092/092_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/093/093_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/094/094_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/095/095_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/096/096_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/097/097_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/098/098_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f2cf470): ../Train/099/099_ED.nii has unexpected scales in sform
#
# WARNING: In /tmp/SimpleITK-build/ITK/Modules/IO/NIFTI/src/itkNiftiImageIO.cxx, line 1934
# NiftiImageIO (0x564a5f149970): ../Train/100/100_ED.nii has unexpected scales in sform
#
# /tmp/ipykernel_3259846/2690441315.py:5: FutureWarning: The input object of type 'ScalarImage' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'ScalarImage', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   X_train_ed = np.array([shaper(subject.ed_seg) for subject in subject_list])
# /tmp/ipykernel_3259846/2690441315.py:5: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X_train_ed = np.array([shaper(subject.ed_seg) for subject in subject_list])

# %%
class encoder(nn.Module):

    def __init__(self):
        super().__init__()

        self.conv1 = nn.Conv3d(1, 16, 3, padding=1)
        self.conv2 = nn.Conv3d(16, 32, 3, padding=1)
        self.conv3 = nn.Conv3d(32, 64, 3, padding=1)
        self.conv4 = nn.Conv3d(64, 32, 3, padding=1)
        self.conv5 = nn.Conv3d(32, 16, 3, padding=1)
        self.conv6 = nn.Conv3d(16, 8, 3, padding=1)

        self.maxpool2 = nn.MaxPool3d(2, 2)
        
        self.denseim1 = nn.Linear(int(6656), 128)
        self.denseim2 = nn.Linear(128, 16)

        self.denseclass1 = nn.Linear(30, 12)
        self.denseclass2 = nn.Linear(12, 5)

        """self.batchnorm16 = nn.BatchNorm3d(16)
        self.batchnorm32 = nn.BatchNorm3d(32)
        self.batchnorm64 = nn.BatchNorm3d(64)"""

    def forward(self, im, stats, batchsize):

        image_features = F.relu(self.conv1(im))

        image_features = F.relu(self.conv2(image_features))
        image_features = self.maxpool2(image_features)

        image_features = F.relu(self.conv3(image_features))
        image_features = self.maxpool2(image_features)

        image_features = F.relu(self.conv4(image_features))
        image_features = self.maxpool2(image_features)

        image_features = F.relu(self.conv5(image_features))
        image_features = self.maxpool2(image_features)

        image_features = F.relu(self.conv6(image_features))

        image_features = F.relu(self.denseim1(image_features.view(int(batchsize/(torch.cuda.device_count()-1)), 6656)))
        image_features = F.relu(self.denseim2(image_features))

        features = torch.cat((image_features, stats), dim = 1)

        features = F.relu(self.denseclass1(features))

        classification = F.softmax(self.denseclass2(features), dim = 1)

        return classification
    
class customds(Dataset):
    def __init__(self, images, features, targets):
        self.images = images
        self.features = features
        self.targets = targets

    def __len__(self):
        return len(self.targets)

    def __getitem__(self, index):
        image = self.images[index]
        feature = self.features[index]
        target = self.targets[index]
        return image, feature, target

# %%
model = encoder()
criterion = torch.nn.CrossEntropyLoss()
lr = 0.001
batchsize = 10
optimizer = torch.optim.Adam(model.parameters(), lr = lr)

# %%
images = torch.stack([X_train_ed[i].data for i in range(100)]).float().requires_grad_()
im_mean = torch.mean(images)
im_std = torch.std(images)
images = (images-im_mean)/im_std

classes = torch.from_numpy(classes).float().requires_grad_()
features = torch.from_numpy(features).float().requires_grad_()

dataset = customds(images, features, classes)

dataloader = DataLoader(dataset, batch_size=batchsize, shuffle=True, pin_memory=True)

# %%
def to_device(data, device):

    if isinstance(data, (list, tuple)):
        return [to_device(x, device) for x in data]
        
    return data.to(device, non_blocking = True)

class DeviceDataLoader():

    def __init__(self, dl, device):
        self.dl = dl 
        self.device = device

    def __iter__(self):
        for b in self.dl:
            yield to_device(b, self.device)
    
    def __len__(self):
        return len(self.dl)

def to_device(data, device):
    if isinstance(data, (list,tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)

device = torch.device('cuda:0')
model.to(device)
dataloader = DeviceDataLoader(dataloader, device)


device_ids = [0,1]
if torch.cuda.device_count() > 1:
    print("Using", torch.cuda.device_count(), "GPUs")
    model = nn.DataParallel(model, device_ids=device_ids)

    
model.to(device)
# Out:
# Using 3 GPUs
# DataParallel(
#   (module): encoder(
#     (conv1): Conv3d(1, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (conv2): Conv3d(16, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (conv3): Conv3d(32, 64, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (conv4): Conv3d(64, 32, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (conv5): Conv3d(32, 16, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (conv6): Conv3d(16, 8, kernel_size=(3, 3, 3), stride=(1, 1, 1), padding=(1, 1, 1))
#     (maxpool2): MaxPool3d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (denseim1): Linear(in_features=6656, out_features=128, bias=True)
#     (denseim2): Linear(in_features=128, out_features=16, bias=True)
#     (denseclass1): Linear(in_features=30, out_features=12, bias=True)
#     (denseclass2): Linear(in_features=12, out_features=5, bias=True)
#   )
# )

# %%
def model_acc(predict,labels):
  accuracy = torch.sum(predict == labels).item() / len(labels)
  return accuracy

def vector_to_class(x):
  _, y = torch.max(x, dim = 1)
  return y

# %%
n_epochs = 40
train_losses=[]
valid_losses=[]
i = 0

for epoch in range(0,n_epochs):
  train_loss=0.0
  
  for batch_images, batch_features, batch_targets in dataloader:


    optimizer.zero_grad()
    predict = model(batch_images, batch_features, batchsize)
    # apply loss function
    prediction = vector_to_class(predict).float()
    loss=criterion(prediction,batch_targets)
    # backpropagation
    loss.backward()
    optimizer.step()
    train_loss=loss.item()



  print('Epoch:{} Train Loss:{:.4f}'.format(epoch+1,train_loss/batch_images.shape[0]))
  # calculate accuracy

  print('Accuracy:{:.2f}'.format(model_acc(prediction,batch_targets)))
# END STUDENT CODE
# Out:
# Epoch:1 Train Loss:5.0657
# Accuracy:0.10
# Epoch:2 Train Loss:3.4539
# Accuracy:0.40
# Epoch:3 Train Loss:5.0657
# Accuracy:0.20
# Epoch:4 Train Loss:5.0657
# Accuracy:0.00
# Epoch:5 Train Loss:3.2236
# Accuracy:0.40
# Epoch:6 Train Loss:4.6052
# Accuracy:0.20
# Epoch:7 Train Loss:5.0657
# Accuracy:0.20
# Epoch:8 Train Loss:5.5262
# Accuracy:0.00
# Epoch:9 Train Loss:5.2959
# Accuracy:0.20
# Epoch:10 Train Loss:3.9144
# Accuracy:0.10
# Epoch:11 Train Loss:4.1447
# Accuracy:0.20
# Epoch:12 Train Loss:4.8294
# Accuracy:0.40
# Epoch:13 Train Loss:5.5262
# Accuracy:0.00
# Epoch:14 Train Loss:4.3749
# Accuracy:0.20
# Epoch:15 Train Loss:3.4539
# Accuracy:0.30
# Epoch:16 Train Loss:5.7565
# Accuracy:0.00
# Epoch:17 Train Loss:4.8294
# Accuracy:0.50
# Epoch:18 Train Loss:4.4924
# Accuracy:0.50
# Epoch:19 Train Loss:3.6841
# Accuracy:0.30
# Epoch:20 Train Loss:4.6052
# Accuracy:0.20
# Epoch:21 Train Loss:7.1886
# Accuracy:0.30
# Epoch:22 Train Loss:4.1447
# Accuracy:0.30
# Epoch:23 Train Loss:4.6052
# Accuracy:0.20
# Epoch:24 Train Loss:4.3749
# Accuracy:0.00
# Epoch:25 Train Loss:3.4539
# Accuracy:0.30
# Epoch:26 Train Loss:5.7565
# Accuracy:0.10
# Epoch:27 Train Loss:3.9144
# Accuracy:0.20
# Epoch:28 Train Loss:2.0723
# Accuracy:0.40
# Epoch:29 Train Loss:4.1447
# Accuracy:0.50
# Epoch:30 Train Loss:6.2170
# Accuracy:0.20
# Epoch:31 Train Loss:4.6052
# Accuracy:0.10
# Epoch:32 Train Loss:4.3749
# Accuracy:0.30
# Epoch:33 Train Loss:4.8294
# Accuracy:0.30
# Epoch:34 Train Loss:3.2236
# Accuracy:0.40
# Epoch:35 Train Loss:4.3749
# Accuracy:0.20
# Epoch:36 Train Loss:4.3749
# Accuracy:0.10
# Epoch:37 Train Loss:4.1447
# Accuracy:0.10
# Epoch:38 Train Loss:5.9867
# Accuracy:0.20
# Epoch:39 Train Loss:3.6841
# Accuracy:0.30
# Epoch:40 Train Loss:3.9144
# Accuracy:0.30

# %%
13312/6656
# Out:
# 2.0
